# %% [markdown]
# #1205
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #1211
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #1241
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #1264
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #1270.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #1285.
#
# ![image.png](attachment:image.png)
