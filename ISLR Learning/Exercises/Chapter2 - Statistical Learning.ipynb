# %% [markdown]
# ## 2.4 Exercises
#
# ### Conceptual

# %% [markdown]
# ### 1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.

# %% [markdown]
# ### (a) The sample size n is extremely large, and the number of predictors p is small.
#
# ### My ans:
#
# #### We would expect a flexible statistical learning method to be better because the less inflexible method may not be able to capture  the pattern of the data
#
#
# ### Jeffrey:
# #### In the case of large  n, small  p, it would be best to use a <font color = 'blue'> complex learning</font> method. Since there are only a few  p relative to the number of observations, the flexible method should be able to <font color = 'blue'> accurately capture the true f</font> without the complexity of the flexible model becoming out of control.

# %% [markdown]
# ### (b) The number of predictors p is extremely large, and the number of observations n is small.
#
# ### My ans.
#
# #### In this case, a less felxible learning method might be better to prevent overfitting
#
#
# ### J.
#
# #### In the case of small  n, large  p, it would be <font color = 'blue'>worse to use a flexible model</font>. Flexible models require <font color = 'blue'>a large number of observations</font> or we start fitting to the noise too much. In addition, our problem may even be <font color = 'blue'>underdetermined</font>.

# %% [markdown]
# ### (c) The relationship between the predictors and response is highly non-linear.
#
# ### My ans.
#
# #### Since the relationship is non-linear, it might be able to use more flexible methods to capture the nonlinear relationship. Otherwise, the underfitting may occur.
#
#
# ### J.
#
# #### If the relationship between X and Y is highly non-linear, we would expect flexible methods to be better. Flexible methods can <font color = 'blue'>fit to arbitrary f much better</font>.

# %% [markdown]
# ### (d) The variance of the error terms, i.e. σ2 = Var(epsilon), is extremely high.
#
# ### My ans.
#
# #### In this case, it much be better to use inflexible methods for the model not to capture too much noise of the data
#
#
# ### J.
#
# #### If  Var(ϵ) is extremely high,<font color = 'blue'> a flexible model would be worse</font>. This is because the flexible model will start fitting to the high variance whereas the rigid model will be more robust in ignoring the variance.

# %% [markdown]
# ### 2. Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.

# %% [markdown]
# ### (a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.

# %% [markdown]
# ### My Ans.:
#
# #### This is a regression problem since the dependent variable (CEO's salary is continuous). In this case, we are more interested in inference.
#
# #### n = 500, p = 3

# %% [markdown]
# ### (b) We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.

# %% [markdown]
# ### My Ans:
#
# #### This is a classification problem, our goal is to predict whether the product will be a sucess or a failure, so we are more interested in prediction.
#
#
# #### n = 20 p = 13
#
#
# ### J.
#
# #### As further justification that we are interested in prediction, the interplay between the variables and the outcome of the product will probably be <font color = 'blue'>highly non-linear</font> resulting in using <font color = 'blue'>flexible models with  uninterpretable results</font>.

# %% [markdown]
# ### (c) We are interest in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.

# %% [markdown]
# ### My Ans:
#
# #### This is a regression prediction problem because we are predicting % change in the USD/Euro exchange, which is continuous.
#
# #### n = 52 (weekly data) p = 3

# %% [markdown]
# ### 5. What are the advantages and disadvantages of a very flexible (versus a less flexible) approach for regression or classification? Under what circumstances might a more flexible approach be preferred to a less flexible approach? When might a less flexible approach be preferred?

# %% [markdown]
# ### My Ans.
#
# #### The advantage of using a very felxible approach is that it can capture highly non-linear relationship between independent and dependent variables, and thus to have more accurate prediction results. The distanvantge is that it can easily capture noise of data, and thus encounter overfitting problem, that is, it is hard to generalize new examples that the model did not see before.
#
# #### When dataset is quite large and predictors is relatively small, it is prefer to use more flexible approach
#
# #### The advantage of the less flexible approach is that it is more robust to high variance data, but because of this reason, it may easily suffer underfitting problem, that when the relationship between the dependent and independent variables are highly-nonlinear, the model will not have a way to capture such relationship, and thus cannot accurately predict the dependent variable.
#
# #### When the dataset is relatively small, and there are a lot of features, the less flexible approach might be preferred.
#
#
# ### J.
#
# #### Flexible models are able to capture a much <font color = 'blue'>wider range of  f’s</font>. They however, come <font color = 'blue'>at the cost of needing more training data</font> in proportion to the observed response variables. In addition, their results may be <font color = 'blue'> hard to interpret</font>. A more flexible approach may be appropriate when <font color = 'blue'>given a large  n</font> (see #2, a.), when <font color = 'blue'>the relationship between X and Y is not obvious</font>.
#
# #### A less flexible approach is preferred if we have<font color = 'blue'> a small  n, interpretation is the goal</font>, or when the <font color = 'blue'>possible shapes of f's limited and understood</font>.

# %% [markdown]
# ### 6. Describe the differences between a parametric and a non-parametric statistical learning approach. What are the advantages of a parametric approach to regression or classification (as opposed to a nonparametric approach)? What are its disadvantages?

# %% [markdown]
# ### My Ans:
#
# #### A parametric model needs to estimate unknown parameters and using the estimated parameter values to establish the relationship between the independent and dependent variables; while the non-parametrci methods do not require any parameter estimation.
#
# #### The parametric approach may provide more accurate prediction results but it may produce errors in the process of estimating.
#
#
# ### J.
#
# #### A parametric approach has <font color = 'blue'>parameters</font> that control the model in an fixed way. These may be <font color = 'blue'>coefficients of a line, parameters for parametrized distrubtions, or even statistics of central tendency</font>.
#
# #### Non-parametric approaches general try to<font color = 'blue'> estimate the shape of  f directly from the data</font>, like using <font color = 'blue'>nearest neighbors</font> to guess Y.
#
# #### A parametric approach allows one to understand the<font color = 'blue'> interaction between the X and the Y</font>. For example, if we have the coefficient of some Xi, say  βi, then we can figure out how changing  Xi might change  Y. <font color = 'blue'>Parametric models also require less data</font>. However, if we get the <font color = 'blue'>model assumptions wrong</font>, then parametric approaches can give poor results.

# %% [markdown]
# ### 7. The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.
#
# ![image.png](attachment:image.png)
#
# ### Suppose we wish to use this data set to make a prediction for Y when X1 = X2 = X3 = 0 using K-nearest neighbors.

# %% [markdown]
# ### (a) Compute the Euclidean distance between each observation and the test point, X1 = X2 = X3 = 0.

# %%
import pandas as pd
import numpy as np

Obs = [1,2,3,4,5,6]
X1 = [0,2,0,0,-1,1]
X2 = [3,0,1,1,0,1]
X3 = [0,0,3,2,1,1]
Y = ['Red','Red','Red','Green','Green','Red']

df = pd.DataFrame({'Obs':Obs,'X1':X1,'X2':X2,'X3':X3,'Y':Y})
df
# Out:
#    Obs  X1  X2  X3      Y
# 0    1   0   3   0    Red
# 1    2   2   0   0    Red
# 2    3   0   1   3    Red
# 3    4   0   1   2  Green
# 4    5  -1   0   1  Green
# 5    6   1   1   1    Red

# %%
df['euclidean_dist'] = df.apply(lambda x: np.sqrt(np.sum(x[['X1','X2','X3']]**2)),axis = 1)

df
# Out:
#    Obs  X1  X2  X3      Y  euclidean_dist
# 0    1   0   3   0    Red        3.000000
# 1    2   2   0   0    Red        2.000000
# 2    3   0   1   3    Red        3.162278
# 3    4   0   1   2  Green        2.236068
# 4    5  -1   0   1  Green        1.414214
# 5    6   1   1   1    Red        1.732051

# %% [markdown]
# ### (b) What is our prediction with K = 1? Why?

# %% [markdown]
# #### When K = 1, the nearest neighbor is observation 5, so our prediciton would be "Green"

# %% [markdown]
# ### (c) What is our prediction with K = 3? Why?

# %% [markdown]
# #### When K = 3, the nereast neighbors are observations 5,6, and 2, and they are "Green", "Red" and "Red", so our prediction would be "Red"

# %% [markdown]
# ### (d) If the Bayes decision boundary in this problem is highly nonlinear, then would we expect the best value for K to be large or small? Why?

# %% [markdown]
# #### If the decision boundary is highly nonlinear, which means that you need high complex model to predict, and thus we would expect the best value for K to be small.
#
#
# ### J.
#
# #### We would expect it the best  K to be<font color = 'blue'> small</font>. The reason is that the <font color = 'blue'>higher the  K is, the more far away points we bring in. Over longer distances, the Bayes decision boundary can change a lot</font>.

# %% [markdown]
# ## Applied

# %% [markdown]
# ### This exercise relates to the College data set, which can be found in the file College.csv. It contains a number of variables for 777 different universities and colleges in the US. The variables are
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

college = pd.read_csv('./Data/College.csv',index_col = 0)
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### produce a scatterplot matrix of the first ten columns or variables of the data

# %%
_ = sns.pairplot(college.iloc[:,:10])

# %% [markdown]
# ### To produce side-by-side boxplots of Outstate versus Private.

# %%
_ = sns.boxplot('Private','Outstate',data = college)

# %% [markdown]
# ### Create a new qualitative variable, called Elite, by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.

# %%
college['Elite'] = college['Top10perc'].apply(lambda x: 'Yes' if x >50 else 'No')

college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %%
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
_ = sns.boxplot('Elite','Outstate',data = college)

# %% [markdown]
# ### Use the hist() function to produce some histograms with differing numbers of bins for a few of the quantitative variables.

# %%
fig,ax = plt.subplots(2,2,tight_layout = True,figsize = (10,6))
ax = ax.flatten()

columns = ['Outstate','Expend','Personal','Books']

for i in range(4):
    _ = ax[i].hist(college[columns[i]],bins = 20)
    ax[i].set_xlabel(columns[i])

# %% [markdown]
# ### 9. This exercise involves the Auto data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
auto = pd.read_csv('./Data/Auto.csv')
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0        130    3504          12.0    70
# 1  15.0          8         350.0        165    3693          11.5    70
# 2  18.0          8         318.0        150    3436          11.0    70
# 3  16.0          8         304.0        150    3433          12.0    70
# 4  17.0          8         302.0        140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  397.000000  397.000000    397.000000   397.000000    397.000000
# mean    23.515869    5.458438    193.532746  2970.261965     15.555668
# std      7.825804    1.701577    104.379583   847.904119      2.749995
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.000000     13.800000
# 50%     23.000000    4.000000    146.000000  2800.000000     15.500000
# 75%     29.000000    8.000000    262.000000  3609.000000     17.100000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#              year      origin
# count  397.000000  397.000000
# mean    75.994962    1.574307
# std      3.690005    0.802549
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
remove_ob = auto.drop(auto.index[9:85])

len(remove_ob)
# Out:
# 321

# %%
remove_ob.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  321.000000  321.000000    321.000000   321.000000    321.000000
# mean    24.438629    5.370717    187.049844  2933.962617     15.723053
# std      7.908184    1.653486     99.635385   810.642938      2.680514
# min     11.000000    3.000000     68.000000  1649.000000      8.500000
# 25%     18.000000    4.000000    100.000000  2215.000000     14.000000
# 50%     23.900000    4.000000    145.000000  2795.000000     15.500000
# 75%     30.700000    6.000000    250.000000  3504.000000     17.300000
# max     46.600000    8.000000    455.000000  4997.000000     24.800000
#
#              year      origin
# count  321.000000  321.000000
# mean    77.152648    1.598131
# std      3.111230    0.816163
# min     70.000000    1.000000
# 25%     75.000000    1.000000
# 50%     77.000000    1.000000
# 75%     80.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ### Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
_ = sns.pairplot(auto)
